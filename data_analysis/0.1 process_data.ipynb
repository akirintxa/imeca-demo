# %% [markdown]
# ## 0.1 Process data

# %%
import pandas as pd

# %%
# Unir los dos DataFrames en uno
df_total = pd.concat([df_del, df_pal], ignore_index=True)
df_total.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Unir los dos DataFrames en uno
# ----> 2 df_total = pd.concat([df_del, df_pal], ignore_index=True)
#       3 df_total.info()
#
# NameError: name 'df_del' is not defined
